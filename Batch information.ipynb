# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import wordcloud

# %%
batch_info=pd.read_csv('batch_info.csv')

# %%
batch_info.head()
# Out:
#            Time               Email Address                 Name  \
# 0  8/1/20 23:05      deepanjan325@gmail.com     Deepanjan Biswas
# 1  8/1/20 23:06  ranubanerjee1984@gmail.com        RANU BANERJEE
# 2  8/1/20 23:08      sharmisthaad@gmail.com  Sharmistha Adhikari
# 3  8/1/20 23:10       saikat20171@gmail.com         Saikat Mitra
# 4  8/1/20 23:10    rahulroystat36@gmail.com            Rahul Roy
#
#    How well you guys are understanding the covered topics ?  \
# 0                                                5.0
# 1                                                5.0
# 2                                                1.0
# 3                                                4.0
# 4                                                5.0
#
#    Rate our way of training  How well your queries are getting solved   \
# 0                       5.0                                        5.0
# 1                       5.0                                        5.0
# 2                       1.0                                        1.0
# 3                       5.0                                        5.0
# 4                       5.0                                        5.0
#
#   Would you like to join our full time course ?  \
# 0                                           Yes
# 1                                         Maybe
# 2                                         Maybe
# 3                                         Maybe
# 4                                           Yes
#
#   Would you like to recommend this course to others ?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Would you like to apply for paid internship programme by Softanbees  ?  \
# 0                                                Yes
# 1                                              Maybe
# 2                                              Maybe
# 3                                                Yes
# 4                                                Yes
#
#   Your suggestion for improving the training programme (Any other queries)  \
# 0                                                NaN
# 1                                                 NO
# 2                                                NaN
# 3                                        All is well
# 4  I want to know if you r going to tell us how t...
#
#   Please describe Here Please describe here  \
# 0                  NaN                  NaN
# 1                   No                  NaN
# 2                  NaN                  NaN
# 3                  NaN                  NaN
# 4                  NaN                  NaN
#
#   Would you like to recommend this course to others ?.1
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
batch_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 13 columns):
#  Time                                                                       163 non-null object
# Email Address                                                               163 non-null object
# Name                                                                        163 non-null object
# How well you guys are understanding the covered topics ?                    163 non-null float64
# Rate our way of training                                                    163 non-null float64
# How well your queries are getting solved                                    163 non-null float64
# Would you like to join our full time course ?                               163 non-null object
# Would you like to recommend this course to others ?                         67 non-null object
# Would you like to apply for paid internship programme by Softanbees  ?      163 non-null object
# Your suggestion for improving the training programme (Any other queries)    77 non-null object
# Please describe Here                                                        34 non-null object
# Please describe here                                                        2 non-null object
# Would you like to recommend this course to others ?.1                       96 non-null object
# dtypes: float64(3), object(10)
# memory usage: 10.4+ KB

# %%
batch_info=batch_info.drop(columns=['Please describe Here','Please describe here','Would you like to recommend this course to others ?.1'])

# %%
batch_info.columns=['Time','Email','Name','Understand topic(rate 1-5)','Training curriculum(rating)','Query solved(rating)','Join fulltime course?','Recommend course to others?','Apply for paid internship?','Suggestion for imporvement']

# %%
batch_info['Time']=pd.to_datetime(batch_info['Time'],errors='coerce')

# %%
batch_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 10 columns):
# Time                           163 non-null datetime64[ns]
# Email                          163 non-null object
# Name                           163 non-null object
# Understand topic(rate 1-5)     163 non-null float64
# Training curriculum(rating)    163 non-null float64
# Query solved(rating)           163 non-null float64
# Join fulltime course?          163 non-null object
# Recommend course to others?    67 non-null object
# Apply for paid internship?     163 non-null object
# Suggestion for imporvement     77 non-null object
# dtypes: datetime64[ns](1), float64(3), object(6)
# memory usage: 9.1+ KB

# %%
batch_info.isna().sum()
# Out:
# Time                            2
# 148            Rajanya Dutta                         5.0
# 149           Ritwick Mondal                         5.0
# 150              Rupsa mitra                         5.0
# 151           Samriddhi jain                         4.0
# 152    Sanghita chakraborty                          4.0
# 153           Sarbani Thakur                         4.0
# 154           Soham Banerjee                         4.0
# 155          Soham Sen Gupta                         5.0
# 156               Sohini Pal                         3.0
# 157             SONALI SAREN                         5.0
# 158         Sourav Kumar Dan                         3.0
# 159         Srijani Adhikary                         5.0
# 160  Suvargha Ghosh Dastidar                         4.0
# 161                Titas Dey                         5.0
# 162             Trisha Dutta                         4.0
#
#      Training curriculum(rating)  Query solved(rating) Join fulltime course?  \
# 0                            5.0                   5.0                   Yes
# 1                            5.0                   5.0                 Maybe
# 2                            1.0                   1.0                 Maybe
# 3                            5.0                   5.0                 Maybe
# 4                            5.0                   5.0                   Yes
# 5                            3.0                   3.0                 Maybe
# 6                            5.0                   5.0                 Maybe
# 7                            5.0                   5.0                   Yes
# 8                            5.0                   5.0                   Yes
# 9                            5.0                   5.0                 Maybe
# 10                           5.0                   5.0                   Yes
# 11                           5.0                   5.0                    No
# 12                           5.0                   5.0                   Yes
# 13                           4.0                   4.0                 Maybe
# 14                           5.0                   4.0                 Maybe
# 15                           5.0                   5.0                 Maybe
# 16                           5.0                   5.0                 Maybe
# 17                           5.0                   5.0                    No
# 18                           5.0                   5.0                   Yes
# 19                           5.0                   5.0                   Yes
# 20                           5.0                   5.0                   Yes
# 21                           4.0                   5.0                 Maybe
# 22                           5.0                   5.0                    No
# 23                           4.0                   4.0                 Maybe
# 24                           5.0                   5.0                    No
# 25                           5.0                   5.0                 Maybe
# 26                           5.0                   5.0                 Maybe
# 27                           4.0                   5.0                    No
# 28                           5.0                   5.0                 Maybe
# 29                           5.0                   4.0                    No
# ..                           ...                   ...                   ...
# 133                          5.0                   5.0                 Maybe
# 134                          5.0                   5.0                 Maybe
# 135                          5.0                   5.0                 Maybe
# 136                          4.0                   4.0                 Maybe
# 137                          4.0                   5.0                   Yes
# 138                          5.0                   5.0                 Maybe
# 139                          5.0                   5.0                 Maybe
# 140                          4.0                   4.0                    No
# 141                          5.0                   5.0                 Maybe
# 142                          5.0                   5.0                 Maybe
# 143                          5.0                   5.0                    No
# 144                          2.0                   3.0                   Yes
# 145                          4.0                   4.0                   Yes
# 146                          5.0                   5.0                    No
# 147                          5.0                   5.0                   Yes
# 148                          5.0                   5.0                 Maybe
# 149                          5.0                   5.0                    No
# 150                          5.0                   5.0                   Yes
# 151                          4.0                   5.0                 Maybe
# 152                          4.0                   4.0                 Maybe
# 153                          4.0                   4.0                    No
# 154                          4.0                   4.0                 Maybe
# 155                          5.0                   5.0                 Maybe
# 156                          4.0                   4.0                 Maybe
# 157                          5.0                   5.0                 Maybe
# 158                          4.0                   4.0                   Yes
# 159                          5.0                   5.0                 Maybe
# 160                          5.0                   5.0                 Maybe
# 161                          5.0                   5.0                 Maybe
# 162                          4.0                   5.0                   Yes
#
#     Recommend course to others? Apply for paid internship?  \
# 0                           Yes                        Yes
# 1                           Yes                      Maybe
# 2                           Yes                      Maybe
# 3                           Yes                        Yes
# 4                           Yes                        Yes
# 5                         Maybe                      Maybe
# 6                           Yes                        Yes
# 7                           Yes                        Yes
# 8                           Yes                        Yes
# 9                           Yes                        Yes
# 10                          Yes                        Yes
# 11                          Yes                      Maybe
# 12                          Yes                        Yes
# 13                        Maybe                      Maybe
# 14                          Yes                      Maybe
# 15                          Yes                      Maybe
# 16                          Yes                      Maybe
# 17                          Yes                         No
# 18                        Maybe                        Yes
# 19                          Yes                        Yes
# 20                          Yes                        Yes
# 21                          Yes                      Maybe
# 22                          Yes                      Maybe
# 23                        Maybe                        Yes
# 24                          Yes                        Yes
# 25                          Yes                      Maybe
# 26                          Yes                      Maybe
# 27                          Yes                      Maybe
# 28                          Yes                      Maybe
# 29                          Yes                      Maybe
# ..                          ...                        ...
# 133                       maybe                      Maybe
# 134                       maybe                      Maybe
# 135                       maybe                      Maybe
# 136                       maybe                        Yes
# 137                       maybe                        Yes
# 138                       maybe                        Yes
# 139                       maybe                         No
# 140                       maybe                         No
# 141                       maybe                      Maybe
# 142                       maybe                        Yes
# 143                       maybe                         No
# 144                       maybe                        Yes
# 145                       maybe                        Yes
# 146                       maybe                         No
# 147                       maybe                        Yes
# 148                       maybe                      Maybe
# 149                       maybe                         No
# 150                       maybe                        Yes
# 151                       maybe                      Maybe
# 152                       maybe                      Maybe
# 153                       maybe                         No
# 154                       maybe                      Maybe
# 155                       maybe                      Maybe
# 156                       maybe                         No
# 157                       maybe                      Maybe
# 158                       maybe                         No
# 159                       maybe                      Maybe
# 160                       maybe                      Maybe
# 161                       maybe                      Maybe
# 162                       maybe                      Maybe
#
#                             Suggestion for imporvement
# 0                                       No suggestions
# 1                                                   NO
# 2                                       No suggestions
# 3                                          All is well
# 4    I want to know if you r going to tell us how t...
# 5                                       No suggestions
# 6                                      No suggestions.
# 7    I just want to know that we can build our own ...
# 8    The free boot camp was really great. Whatever ...
# 9    This bootcamp was amazing, faculties are so fr...
# 10   As per my suggestion, the way you guys are app...
# 11                               Everything was smooth
# 12                                    So far its good.
# 13   After all its a very great and very helpful se...
# 14   It's very good, but I think if I had prior kno...
# 15   This is completely fine. I am benefitted. Doub...
# 16                                      No suggestions
# 17                                      No suggestions
# 18                  Boot camp was very informative...
# 19                     Its a nice and friendly session
# 20   The free boot camp was great. Whatever was tau...
# 21    Stat portion should be taught with more depth...
# 22   Nothing. This way of teaching is far more bett...
# 23                                      No suggestions
# 24                                      No suggestions
# 25   No suggestion, in today's life no one gives a ...
# 26                          It was a great boot camp .
# 27   It was a fun experience. Some well known topic...
# 28                                      No suggestions
# 29                                      No suggestions
# ..                                                 ...
# 133                                     No suggestions
# 134                                     No suggestions
# 135                                     No suggestions
# 136  The course can be a little longer. Focus on da...
# 137                                           Awesome
# 138                                     No suggestions
# 139                                     No suggestions
# 140                                     No suggestions
# 141                                     No suggestions
# 142                                     No suggestions
# 143       I thnik this is all anyone can do, its good.
# 144  Improving the accent can attract more avid lea...
# 145                                     No suggestions
# 146                                     No suggestions
# 147  The Some queries regarding the full time cours...
# 148  I had an amazing experience; no improvement ne...
# 149                                     No suggestions
# 150  No this training program is really very intere...
# 151            I am satisfied with the way it is now.
# 152                                     No suggestions
# 153                                     No suggestions
# 154                                     No suggestions
# 155  I think it is completely ok. Very  Very intere...
# 156  Increase the workshop day..so that it covers u...
# 157                                     No suggestions
# 158                                     No suggestions
# 159                                                No
# 160            The training programme was quite good.
# 161                                     No suggestions
# 162                           Training program is good
#
# [163 rows x 10 columns]

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import string
import collections

# %%
batch=batch_info['Suggestion for imporvement'].str.lower()

# %%
batch
# Out:
# 0                                         no suggestions
# 1                                                     no
# 2                                         no suggestions
# 3                                            all is well
# 4      i want to know if you r going to tell us how t...
# 5                                         no suggestions
# 6                                        no suggestions.
# 7      i just want to know that we can build our own ...
# 8      the free boot camp was really great. whatever ...
# 9      this bootcamp was amazing, faculties are so fr...
# 10     as per my suggestion, the way you guys are app...
# 11                                 everything was smooth
# 12                                      so far its good.
# 13     after all its a very great and very helpful se...
# 14     it's very good, but i think if i had prior kno...
# 15     this is completely fine. i am benefitted. doub...
# 16                                        no suggestions
# 17                                        no suggestions
# 18                    boot camp was very informative...
# 19                       its a nice and friendly session
# 20     the free boot camp was great. whatever was tau...
# 21      stat portion should be taught with more depth...
# 22     nothing. this way of teaching is far more bett...
# 23                                        no suggestions
# 24                                        no suggestions
# 25     no suggestion, in today's life no one gives a ...
# 26                            it was a great boot camp .
# 27     it was a fun experience. some well known topic...
# 28                                        no suggestions
# 29                                        no suggestions
#                              ...
# 133                                       no suggestions
# 134                                       no suggestions
# 135                                       no suggestions
# 136    the course can be a little longer. focus on da...
# 137                                             awesome
# 138                                       no suggestions
# 139                                       no suggestions
# 140                                       no suggestions
# 141                                       no suggestions
# 142                                       no suggestions
# 143         i thnik this is all anyone can do, its good.
# 144    improving the accent can attract more avid lea...
# 145                                       no suggestions
# 146                                       no suggestions
# 147    the some queries regarding the full time cours...
# 148    i had an amazing experience; no improvement ne...
# 149                                       no suggestions
# 150    no this training program is really very intere...
# 151              i am satisfied with the way it is now.
# 152                                       no suggestions
# 153                                       no suggestions
# 154                                       no suggestions
# 155    i think it is completely ok. very  very intere...
# 156    increase the workshop day..so that it covers u...
# 157                                       no suggestions
# 158                                       no suggestions
# 159                                                  no
# 160              the training programme was quite good.
# 161                                       no suggestions
# 162                             training program is good
# Name: Suggestion for imporvement, Length: 163, dtype: object

# %%
all_suggest=batch.str.split(' ')
all_suggest
# Out:
# 0                                      [no, suggestions]
# 1                                                   [no]
# 2                                      [no, suggestions]
# 3                                        [all, is, well]
# 4      [i, want, to, know, if, you, r, going, to, tel...
# 5                                      [no, suggestions]
# 6                                     [no, suggestions.]
# 7      [i, just, want, to, know, that, we, can, build...
# 8      [the, free, boot, camp, was, really, great., w...
# 9      [this, bootcamp, was, amazing,, faculties, are...
# 10     [as, per, my, suggestion,, the, way, you, guys...
# 11                             [everything, was, smooth]
# 12                                 [so, far, its, good.]
# 13     [after, all, its, a, very, great, and, very, h...
# 14     [it's, very, good,, but, i, think, if, i, had,...
# 15     [this, is, completely, fine., i, am, benefitte...
# 16                                     [no, suggestions]
# 17                                     [no, suggestions]
# 18             [boot, camp, was, very, informative..., ]
# 19                [its, a, nice, and, friendly, session]
# 20     [the, free, boot, camp, was, great., whatever,...
# 21     [stat, portion, should, be, taught, with, more...
# 22     [nothing., this, way, of, teaching, is, far, m...
# 23                                     [no, suggestions]
# 24                                     [no, suggestions]
# 25     [no, suggestion,, in, today's, life, no, one, ...
# 26                    [it, was, a, great, boot, camp, .]
# 27     [it, was, a, fun, experience., some, well, kno...
# 28                                     [no, suggestions]
# 29                                     [no, suggestions]
#                              ...
# 133                                    [no, suggestions]
# 134                                    [no, suggestions]
# 135                                    [no, suggestions]
# 136    [the, course, can, be, a, little, longer., foc...
# 137                                          [awesome, ]
# 138                                    [no, suggestions]
# 139                                    [no, suggestions]
# 140                                    [no, suggestions]
# 141                                    [no, suggestions]
# 142                                    [no, suggestions]
# 143    [i, thnik, this, is, all, anyone, can, do,, it...
# 144    [improving, the, accent, can, attract, more, a...
# 145                                    [no, suggestions]
# 146                                    [no, suggestions]
# 147    [the, some, queries, regarding, the, full, tim...
# 148    [i, had, an, amazing, experience;, no, improve...
# 149                                    [no, suggestions]
# 150    [no, this, training, program, is, really, very...
# 151    [i, am, satisfied, with, the, way, it, is, now...
# 152                                    [no, suggestions]
# 153                                    [no, suggestions]
# 154                                    [no, suggestions]
# 155    [i, think, it, is, completely, ok., very, , ve...
# 156    [increase, the, workshop, day..so, that, it, c...
# 157                                    [no, suggestions]
# 158                                    [no, suggestions]
# 159                                               [no, ]
# 160      [the, training, programme, was, quite, good., ]
# 161                                    [no, suggestions]
# 162                        [training, program, is, good]
# Name: Suggestion for imporvement, Length: 163, dtype: object

# %%
all_suggestion=[]

for text in all_suggest:
    text = [x.strip(string.punctuation) for x in text]
    all_suggestion.append(text)

all_suggestion[0]

text_suggest = [" ".join(text) for text in all_suggestion]
final_text_suggest = " ".join(text_suggest)
final_text_suggest[:]
# Out:
# "no suggestions no no suggestions all is well i want to know if you r going to tell us how to create app like shankha da present after session no suggestions no suggestions i just want to know that we can build our own app like shankha da present us after session on a dam project on a synthetic data set the free boot camp was really great whatever lessons on r was given was really helpful thank you this bootcamp was amazing faculties are so friendly  well behaved according to me there is no need of improving the training program,this was at its best  as per my suggestion the way you guys are approaching is really good and i am quite sure you will carry on this quality of training in future al the best everything was smooth so far its good after all its a very great and very helpful session for me....mainly as a friendly teaching process....thanking you surya da(rittik da,sankhadeep da,rishikesh da it's very good but i think if i had prior knowledge on coding then it would be more easy to understand this is completely fine i am benefitted doubts are easily cleared  no suggestions no suggestions boot camp was very informative  its a nice and friendly session the free boot camp was great whatever was taught in r was very helpful thank you stat portion should be taught with more depth nothing this way of teaching is far more better than many other places  no suggestions no suggestions no suggestion in today's life no one gives a second from their life but sir all of your team members are doing a great i didn't have any knowledge about data science but at least now i know about this a little thank you very much for the sessions  it was a great boot camp  it was a fun experience some well known topics were taught in an interesting manner the details of basic stats though necessary was a bit tedious no suggestions no suggestions no suggestions no suggestions no suggestions because the training is good and also good to learn new things  it would be beneficial if people from similar backgrounds are put into the same batch during the training no no suggestions no suggestions no queries it was a great session softanbees free boot camp session provides a wonderful platform for enlightening the concepts of data analysis using r programming it shows how even coding can be so easy and fun to learn no suggestions no suggestions no no suggestions no suggestions...it's already the best👍 there is literally no loopholes it's beyond perfect...thank you very much keep up the good work  if we could get to work on live projects that could help us understand concepts in detail  in paid course   as boot camp it was very good  no suggestions it's my pleasure to give me a chance to learn that things  it's the best....no more suggestions this is the best way of teaching programming that i've ever seen.the way of teaching is so good that anyone can understand programming at ease i feel fortunate enough to be a part of this training i got no suggestions for improving the training programme because this is perfect the way you  your team shown  presented the real-time project...that's great bro   the reason for maybe is that at present  i'm an intern getting paid  in starting unable to manage time i've the linkedin connection  contact no of mr surya so when i'll be comfortable with my office timing i'll ping him  stepping towards ds no suggestions no suggestions if this program appears with at least one home assignment then it would help in better understanding  no suggestions perfect way of explaining nothing to change  no suggestions no suggestions nothing.it really good.carry on no suggestions no suggestions there is literally no loopholes it's beyond perfect...thank you very much the session is awesome and pretty much interesting somehow i missed some session due to poor connectivity i am going through with the recordings times spent with these things are very much appreciated thank you.(regards are there instead of suggestions no suggestion  no suggestio ...

# %%
wordcloud_suggestion = WordCloud(background_color="black",max_font_size = 60, colormap='Blues',
                      collocations=False).generate(final_text_suggest)

plt.figure(figsize = (15,15))
plt.imshow(wordcloud_suggestion, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
import seaborn as sns

# %%
fig, ax =plt.subplots(1,3,figsize=(18,3))

sns.countplot(batch_info['Understand topic(rate 1-5)'], ax=ax[0])
ax[0].set_title('How well people Understand Coverd Topics')

sns.countplot(batch_info['Training curriculum(rating)'], ax=ax[1])
ax[1].set_title('How well are the training curriculum')

sns.countplot(batch_info['Query solved(rating)'],ax=ax[2])
ax[2].set_title('How fisrt and sincerly query getting solved')

fig.show()
#From the visualization everyone seem to be like the course curriculum as well as coverd topic and everyone satisfied with their query getting solved
# Out:
# C:\Users\User\anaconda3\envs\Bindu1\lib\site-packages\ipykernel_launcher.py:12: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   if sys.path[0] == '':

# %%
set_yes = {"Apply for paid internship?":{"Yes": 1}}
df=pd.DataFrame(batch_info,columns=['Apply for paid internship?','Understand topic(rate 1-5)'])
new_df=df.loc[df['Apply for paid internship?'] == 'Yes'].replace(set_yes)
new_df['Apply for paid internship?']=new_df['Apply for paid internship?'].astype('float')

# %%
new_df.head()
# Out:
#    Apply for paid internship?  Understand topic(rate 1-5)
# 0                         1.0                         5.0
# 3                         1.0                         4.0
# 4                         1.0                         5.0
# 6                         1.0                         5.0
# 7                         1.0                         5.0

# %%
new_df.corr(method='pearson')
# Out:
#                             Apply for paid internship?  \
# Apply for paid internship?                         NaN
# Understand topic(rate 1-5)                         NaN
#
#                             Understand topic(rate 1-5)
# Apply for paid internship?                         NaN
# Understand topic(rate 1-5)                         1.0
